-- %% [markdown]
-- # [Library]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Library]    Script Date: 17/08/2022 12:41:11 ص ******/
CREATE DATABASE [Library]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Library', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Library.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Library_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Library_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Library] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Library].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Library] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Library] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Library] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Library] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Library] SET ARITHABORT OFF 
GO
ALTER DATABASE [Library] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Library] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Library] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Library] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Library] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Library] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Library] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Library] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Library] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Library] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Library] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Library] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Library] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Library] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Library] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Library] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Library] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Library] SET RECOVERY FULL 
GO
ALTER DATABASE [Library] SET  MULTI_USER 
GO
ALTER DATABASE [Library] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Library] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Library] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Library] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Library] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Library] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Library', N'ON'
GO
ALTER DATABASE [Library] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[TbAuthor]

-- %%
USE [Library]
GO

-- %%
/****** Object:  Table [dbo].[TbAuthor]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbAuthor](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
	[Date] [nvarchar](50) NULL,
	[Nationality] [nvarchar](50) NULL,
 CONSTRAINT [PK_TbAuthor] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBookCategory]

-- %%
/****** Object:  Table [dbo].[TbBookCategory]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBookCategory](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
 CONSTRAINT [PK_TbBookCategory] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBookCountry]

-- %%
/****** Object:  Table [dbo].[TbBookCountry]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBookCountry](
	[Id] [int] NOT NULL,
	[Name] [nchar](10) NULL,
 CONSTRAINT [PK_TbBookCountry] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBookPlace]

-- %%
/****** Object:  Table [dbo].[TbBookPlace]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBookPlace](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
 CONSTRAINT [PK_TbBookPlace] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBooksBorrow]

-- %%
/****** Object:  Table [dbo].[TbBooksBorrow]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBooksBorrow](
	[Id] [int] NOT NULL,
	[Borrower_id] [int] NULL,
	[Book_id] [int] NULL,
	[Start_date] [nvarchar](50) NULL,
	[End_date] [nvarchar](50) NULL,
	[Notes] [nvarchar](200) NULL,
 CONSTRAINT [PK_TbBooksBorrow] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBooksData]

-- %%
/****** Object:  Table [dbo].[TbBooksData]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBooksData](
	[Id] [int] NOT NULL,
	[Book_name] [nvarchar](50) NULL,
	[Cat_id] [int] NULL,
	[Author_id] [int] NULL,
	[Country_id] [int] NULL,
	[Dar_id] [int] NULL,
	[SubCat] [nvarchar](50) NULL,
	[Date] [nvarchar](50) NOT NULL,
	[PagesNumber] [int] NULL,
	[Place_id] [int] NULL,
	[Book_status] [nvarchar](50) NULL,
	[Book_price] [real] NULL,
 CONSTRAINT [PK_TbBooksData] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbBorowPerson]

-- %%
/****** Object:  Table [dbo].[TbBorowPerson]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbBorowPerson](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
	[Date] [nvarchar](50) NULL,
	[Phone] [nvarchar](50) NULL,
 CONSTRAINT [PK_TbBorowPerson] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TbDarAlnasher]

-- %%
/****** Object:  Table [dbo].[TbDarAlnasher]    Script Date: 17/08/2022 12:41:11 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TbDarAlnasher](
	[Id] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
	[Country] [nvarchar](50) NULL,
 CONSTRAINT [PK_TbDarAlnasher] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_TbBooksBorrow_TbBooksData]

-- %%
ALTER TABLE [dbo].[TbBooksBorrow]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksBorrow_TbBooksData] FOREIGN KEY([Book_id])
REFERENCES [dbo].[TbBooksData] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksBorrow] CHECK CONSTRAINT [FK_TbBooksBorrow_TbBooksData]
GO

-- %% [markdown]
-- # [FK_TbBooksBorrow_TbBorowPerson]

-- %%
ALTER TABLE [dbo].[TbBooksBorrow]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksBorrow_TbBorowPerson] FOREIGN KEY([Borrower_id])
REFERENCES [dbo].[TbBorowPerson] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksBorrow] CHECK CONSTRAINT [FK_TbBooksBorrow_TbBorowPerson]
GO

-- %% [markdown]
-- # [FK_TbBooksData_TbAuthor]

-- %%
ALTER TABLE [dbo].[TbBooksData]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksData_TbAuthor] FOREIGN KEY([Author_id])
REFERENCES [dbo].[TbAuthor] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksData] CHECK CONSTRAINT [FK_TbBooksData_TbAuthor]
GO

-- %% [markdown]
-- # [FK_TbBooksData_TbBookCategory]

-- %%
ALTER TABLE [dbo].[TbBooksData]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksData_TbBookCategory] FOREIGN KEY([Cat_id])
REFERENCES [dbo].[TbBookCategory] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksData] CHECK CONSTRAINT [FK_TbBooksData_TbBookCategory]
GO

-- %% [markdown]
-- # [FK_TbBooksData_TbBookCountry]

-- %%
ALTER TABLE [dbo].[TbBooksData]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksData_TbBookCountry] FOREIGN KEY([Country_id])
REFERENCES [dbo].[TbBookCountry] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksData] CHECK CONSTRAINT [FK_TbBooksData_TbBookCountry]
GO

-- %% [markdown]
-- # [FK_TbBooksData_TbBookPlace]

-- %%
ALTER TABLE [dbo].[TbBooksData]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksData_TbBookPlace] FOREIGN KEY([Place_id])
REFERENCES [dbo].[TbBookPlace] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksData] CHECK CONSTRAINT [FK_TbBooksData_TbBookPlace]
GO

-- %% [markdown]
-- # [FK_TbBooksData_TbDarAlnasher]

-- %%
ALTER TABLE [dbo].[TbBooksData]  WITH CHECK ADD  CONSTRAINT [FK_TbBooksData_TbDarAlnasher] FOREIGN KEY([Dar_id])
REFERENCES [dbo].[TbDarAlnasher] ([Id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[TbBooksData] CHECK CONSTRAINT [FK_TbBooksData_TbDarAlnasher]
GO

-- %% [markdown]
-- # [Library]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Library] SET  READ_WRITE 
GO
